# %%
from load_data import load_arxiv_data

# %%
df = load_arxiv_data()

# %%
print(f"Total papers: {len(df)}")
print(f"Years range: {df['year'].min()} - {df['year'].max()}")
print(f"Columns: {df.columns.tolist()}")
print(f"Sample categories: {df['categories'].head()}")
df.head()
# Out:
# Total papers: 30529
# Years range: 2007 - 2021
# Columns: ['id', 'submitter', 'authors', 'title', 'comments', 'journal-ref', 'doi', 'abstract', 'report-no', 'categories', 'versions', 'year']
# Sample categories: 1273    [cs.LG]
# 1393    [cs.AI]
# 2009    [cs.AI]
# 2667    [cs.LG]
# 2724    [cs.NE]
# Name: categories, dtype: object
#              id           submitter  \
# 1273  0704.1274      Dev Rajnarayan
# 1393  0704.1394  Tarik Had\v{z}i\'c
# 2009  0704.2010   Juliana Bernardes
# 2667  0704.2668        Alex Smola J
# 2724  0704.2725    Manuel Cebri\'an
#
#                                                 authors  \
# 1273             David H. Wolpert and Dev G. Rajnarayan
# 1393  Tarik Hadzic, Rune Moller Jensen, Henrik Reif ...
# 2009  Juliana S Bernardes, Alberto Davila, Vitor San...
# 2667  Le Song, Alex Smola, Arthur Gretton, Karsten B...
# 2724                   Manuel Cebrian and Ivan Cantador
#
#                                                   title  \
# ...
